# %%
import os
os.listdir('./')
# Out:
# ['svelte.config.js',
#  '.DS_Store',
#  'svg_tooltip.svg',
#  'Untitled.ipynb',
#  'node_modules',
#  'crime_map.csv',
#  '.npmrc',
#  'README.md',
#  'ChicagoDataScience.ipynb',
#  '.gitignore',
#  'package-lock.json',
#  'package.json',
#  'static',
#  'Crimes_-_Map.csv',
#  'chicagodata.json',
#  'tsconfig.json',
#  '.ipynb_checkpoints',
#  '.svelte-kit',
#  'vite.config.ts',
#  '.git',
#  'src']

# %%
import geopandas as gpd
df_neighborhoods = gpd.read_file('./src/Boundaries - Neighborhoods.json')

# %%
import pandas as pd
import numpy as np
df = pd.read_csv('./Crimes_-_Map.csv')
df[' PRIMARY DESCRIPTION'].unique()
df[' PRIMARY DESCRIPTION'].value_counts()
# Out:
# THEFT                                55752
# BATTERY                              41453
# CRIMINAL DAMAGE                      28345
# MOTOR VEHICLE THEFT                  24700
# ASSAULT                              21296
# DECEPTIVE PRACTICE                   15831
# OTHER OFFENSE                        14682
# ROBBERY                               9152
# WEAPONS VIOLATION                     8945
# BURGLARY                              7698
# CRIMINAL TRESPASS                     4443
# NARCOTICS                             4351
# OFFENSE INVOLVING CHILDREN            1910
# CRIMINAL SEXUAL ASSAULT               1516
# SEX OFFENSE                           1209
# PUBLIC PEACE VIOLATION                 748
# HOMICIDE                               702
# STALKING                               452
# ARSON                                  448
# INTERFERENCE WITH PUBLIC OFFICER       416
# PROSTITUTION                           303
# LIQUOR LAW VIOLATION                   216
# INTIMIDATION                           211
# CONCEALED CARRY LICENSE VIOLATION      185
# KIDNAPPING                             123
# OBSCENITY                               52
# HUMAN TRAFFICKING                       11
# GAMBLING                                11
# OTHER NARCOTIC VIOLATION                 8
# PUBLIC INDECENCY                         6
# NON-CRIMINAL                             5
# Name:  PRIMARY DESCRIPTION, dtype: int64

# %%
new_df = df.drop(['CASE#', 'DATE  OF OCCURRENCE', 'BLOCK', ' IUCR', ' SECONDARY DESCRIPTION', ' LOCATION DESCRIPTION', 'BEAT', 'WARD', 'FBI CD', 'X COORDINATE', 'Y COORDINATE', 'LOCATION'], axis=1)
new_df = new_df.dropna()
new_df.insert(0, "NEIGHBORHOOD", np.nan)
new_df.head()
# Out:
#     NEIGHBORHOOD  PRIMARY DESCRIPTION ARREST DOMESTIC   LATITUDE  LONGITUDE
# 11           NaN                THEFT      N        N  41.886801 -87.645920
# 14           NaN              ASSAULT      N        Y  41.880751 -87.723856
# 15           NaN                THEFT      N        N  42.018616 -87.665846
# 33           NaN   DECEPTIVE PRACTICE      N        N  41.806859 -87.732124
# 47           NaN    CRIMINAL TRESPASS      Y        N  41.854763 -87.689136

# %%
import shapely
from shapely.geometry import LineString, Point, Polygon, MultiPolygon
from shapely.strtree import STRtree

index = STRtree(df_neighborhoods.geometry.tolist())

# %%
for ind, i in enumerate(new_df.index):
    point = Point(new_df['LONGITUDE'][i],new_df['LATITUDE'][i])
    for polygon in index.query(point):
        new_df['NEIGHBORHOOD'][i] = (df_neighborhoods['pri_neigh'][polygon])

# %%
df_neighborhoods.head()
# Out:
#             pri_neigh           sec_neigh     shape_area     shape_len  \
# 0     Grand Boulevard         BRONZEVILLE  48492503.1554  28196.837157
# 1        Printers Row        PRINTERS ROW  2162137.97139   6864.247156
# 2       United Center       UNITED CENTER  32520512.7053  23101.363745
# 3  Sheffield & DePaul  SHEFFIELD & DEPAUL  10482592.2987  13227.049745
# 4       Humboldt Park       HUMBOLDT PARK  125010425.593  46126.751351
#
#                                             geometry
# 0  POLYGON ((-87.60671 41.81681, -87.60668 41.815...
# 1  POLYGON ((-87.62742 41.86741, -87.63044 41.867...
# 2  POLYGON ((-87.66707 41.88885, -87.66706 41.887...
# 3  POLYGON ((-87.65871 41.93256, -87.65472 41.932...
# 4  POLYGON ((-87.74060 41.88782, -87.74069 41.890...

# %%
so_df = new_df[(new_df[' PRIMARY DESCRIPTION'] == "MOTOR VEHICLE THEFT")]

# %%
a_df = so_df[so_df['ARREST'] == 'Y']
so_df.head()
# Out:
#           NEIGHBORHOOD  PRIMARY DESCRIPTION ARREST DOMESTIC   LATITUDE  \
# 157             Austin  MOTOR VEHICLE THEFT      N        N  41.912674
# 165          Gage Park  MOTOR VEHICLE THEFT      N        N  41.794691
# 170     Auburn Gresham  MOTOR VEHICLE THEFT      N        N  41.749649
# 173           Avondale  MOTOR VEHICLE THEFT      N        N  41.936854
# 179  Little Italy, UIC  MOTOR VEHICLE THEFT      N        N  41.872965
#
#      LONGITUDE
# 157 -87.752764
# 165 -87.692606
# 170 -87.645227
# 173 -87.720172
# 179 -87.687511

# %%
a_df.value_counts(subset="NEIGHBORHOOD", normalize=False)
# Out:
# NEIGHBORHOOD
# Austin             64
# North Lawndale     30
# Garfield Park      28
# Englewood          23
# Humboldt Park      21
#                    ..
# Calumet Heights     1
# Riverdale           1
# Bridgeport          1
# Beverly             1
# Fuller Park         1
# Length: 76, dtype: int64

# %%
vals = new_df[(new_df[' PRIMARY DESCRIPTION'] == "MOTOR VEHICLE THEFT")]['NEIGHBORHOOD'].value_counts()
vals_ind = vals.index
print(vals)
# Out:
# Austin            1443
# South Shore       1189
# Roseland          1103
# Grand Crossing     981
# Garfield Park      832
#                   ...
# Greektown           16
# Edison Park         12
# Jefferson Park       7
# Burnside             4
# Andersonville        1
# Name: NEIGHBORHOOD, Length: 91, dtype: int64

# %%
df_neighborhoods.insert(0, "num_motor_thefts", np.nan)

# %%
for i in df_neighborhoods['pri_neigh'].index:
    if df_neighborhoods['pri_neigh'][i] in vals_ind:
        df_neighborhoods['num_motor_thefts'][i] = vals[df_neighborhoods['pri_neigh'][i]]
    else:
        df_neighborhoods['num_motor_thefts'][i] = 0
# Out:
# /var/folders/q2/blj1b35943190bxj_nqhbpy0w9ff45/T/ipykernel_5561/4165206342.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_neighborhoods['num_motor_thefts'][i] = vals[df_neighborhoods['pri_neigh'][i]]
# /var/folders/q2/blj1b35943190bxj_nqhbpy0w9ff45/T/ipykernel_5561/4165206342.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_neighborhoods['num_motor_thefts'][i] = 0

# %%
df_neighborhoods.plot(column="num_motor_thefts")
# Out:
# <Axes: >

# %%
df_neighborhoods.to_file("chicagodata.json")

# %%
df_neighborhoods['pri_neigh'][1]
# Out:
# 'Printers Row'

# %%
df_neighborhoods["num_motor_thefts"] = df_neighborhoods["num_motor_thefts"] / 1443

# %%
import matplotlib.pyplot as plt
from mpl_toolkits.axes_grid1 import make_axes_locatable
import mapclassify

df_neighborhoods.plot(column="num_motor_thefts", missing_kwds={'color': 'lightgrey'})

df_neighborhoods.plot(column="num_motor_thefts",
                               edgecolor="black",
                               legend=True,
                               scheme="quantiles",
                               figsize=(15,10),
                               cmap='OrRd',
                               missing_kwds={
                                   "color": "lightgrey",
                                   "edgecolor": "red",
                                   "hatch": "///",
                                   "label": "No theft"
                               }).set_axis_off()

# %%
for i in df_neighborhoods[df_neighborhoods["num_motor_thefts"] == 0].index:
    df_neighborhoods["num_motor_thefts"][i] = np.nan
# Out:
# /var/folders/q2/blj1b35943190bxj_nqhbpy0w9ff45/T/ipykernel_5561/1632226341.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_neighborhoods["num_motor_thefts"][i] = np.nan

# %%
theft_df = new_df[new_df[' PRIMARY DESCRIPTION'] == 'THEFT']
motor_theft_df = new_df[new_df[' PRIMARY DESCRIPTION'] == 'MOTOR VEHICLE THEFT']
motor_theft_df.insert(0, 'geometry', np.nan)
theft_df.insert(0, 'geometry', np.nan)
theft_coords = list(zip(theft_df['LONGITUDE'], theft_df['LATITUDE']))
motor_theft_coords = list(zip(motor_theft_df['LONGITUDE'], theft_df['LATITUDE']))

# %%
for i, ind in enumerate(motor_theft_df['geometry'].index):
     motor_theft_df['geometry'][ind] = Point(motor_theft_df['LONGITUDE'][ind], motor_theft_df['LATITUDE'][ind])

for i, ind in enumerate(theft_df['geometry'].index):
     theft_df['geometry'][ind] = Point(theft_df['LONGITUDE'][ind], theft_df['LATITUDE'][ind])
# Out:
# /var/folders/q2/blj1b35943190bxj_nqhbpy0w9ff45/T/ipykernel_5561/660324257.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   motor_theft_df['geometry'][ind] = Point(motor_theft_df['LONGITUDE'][ind], motor_theft_df['LATITUDE'][ind])
# /var/folders/q2/blj1b35943190bxj_nqhbpy0w9ff45/T/ipykernel_5561/660324257.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   theft_df['geometry'][ind] = Point(theft_df['LONGITUDE'][ind], theft_df['LATITUDE'][ind])

# %%
motor_theft_df
# Out:
#                                   geometry       NEIGHBORHOOD  \
# 157     POINT (-87.752764058 41.912673714)             Austin
# 165     POINT (-87.692605888 41.794690928)          Gage Park
# 170      POINT (-87.64522669 41.749649216)     Auburn Gresham
# 173     POINT (-87.720172313 41.936853833)           Avondale
# 179     POINT (-87.687510515 41.872964607)  Little Italy, UIC
# ...                                    ...                ...
# 245162  POINT (-87.641772074 41.881847601)          West Loop
# 245164  POINT (-87.687393113 41.917061131)           Bucktown
# 245176  POINT (-87.602187052 41.776307684)           Woodlawn
# 245177   POINT (-87.592907065 41.74514439)        Avalon Park
# 245179  POINT (-87.766553683 41.891765632)             Austin
#
#         PRIMARY DESCRIPTION ARREST DOMESTIC   LATITUDE  LONGITUDE
# 157     MOTOR VEHICLE THEFT      N        N  41.912674 -87.752764
# 165     MOTOR VEHICLE THEFT      N        N  41.794691 -87.692606
# 170     MOTOR VEHICLE THEFT      N        N  41.749649 -87.645227
# 173     MOTOR VEHICLE THEFT      N        N  41.936854 -87.720172
# 179     MOTOR VEHICLE THEFT      N        N  41.872965 -87.687511
# ...                     ...    ...      ...        ...        ...
# 245162  MOTOR VEHICLE THEFT      N        N  41.881848 -87.641772
# 245164  MOTOR VEHICLE THEFT      N        N  41.917061 -87.687393
# 245176  MOTOR VEHICLE THEFT      N        N  41.776308 -87.602187
# 245177  MOTOR VEHICLE THEFT      N        N  41.745144 -87.592907
# 245179  MOTOR VEHICLE THEFT      N        N  41.891766 -87.766554
#
# [24536 rows x 7 columns]

# %%
import geoplot as gplt
import geopandas as gpd
import pandas as pd; 


usa_cities = gpd.read_file(gplt.datasets.get_path('usa_cities'))
usa_cities.head()
# Out:
#     id  POP_2010  ELEV_IN_FT STATE                     geometry
# 0   53   40888.0      1611.0    ND  POINT (-101.29627 48.23251)
# 1  101   52838.0       830.0    ND   POINT (-97.03285 47.92526)
# 2  153   15427.0      1407.0    ND   POINT (-98.70844 46.91054)
# 3  177  105549.0       902.0    ND   POINT (-96.78980 46.87719)
# 4  192   17787.0      2411.0    ND  POINT (-102.78962 46.87918)

# %%
continental_usa_cities = usa_cities.query('STATE not in ["HI", "AK", "PR", "TX", "FL"]')
continental_usa_cities.head()
# Out:
#     id  POP_2010  ELEV_IN_FT STATE                     geometry
# 0   53   40888.0      1611.0    ND  POINT (-101.29627 48.23251)
# 1  101   52838.0       830.0    ND   POINT (-97.03285 47.92526)
# 2  153   15427.0      1407.0    ND   POINT (-98.70844 46.91054)
# 3  177  105549.0       902.0    ND   POINT (-96.78980 46.87719)
# 4  192   17787.0      2411.0    ND  POINT (-102.78962 46.87918)

# %%
theft_g = gpd.GeoDataFrame(geometry=theft_df['geometry'])
motor_theft_g = gpd.GeoDataFrame(geometry=motor_theft_df['geometry'])
geometry = gpd.GeoDataFrame(geometry=df_neighborhoods["geometry"])
geometry
# Out:
#                                              geometry
# 0   POLYGON ((-87.60671 41.81681, -87.60668 41.815...
# 1   POLYGON ((-87.62742 41.86741, -87.63044 41.867...
# 2   POLYGON ((-87.66707 41.88885, -87.66706 41.887...
# 3   POLYGON ((-87.65871 41.93256, -87.65472 41.932...
# 4   POLYGON ((-87.74060 41.88782, -87.74069 41.890...
# ..                                                ...
# 93  POLYGON ((-87.74134 41.91390, -87.74601 41.914...
# 94  POLYGON ((-87.74134 41.91390, -87.74130 41.912...
# 95  POLYGON ((-87.62446 41.91157, -87.62466 41.911...
# 96  POLYGON ((-87.64878 41.93999, -87.64927 41.939...
# 97  POLYGON ((-87.63145 41.90390, -87.63136 41.900...
#
# [98 rows x 1 columns]

# %%
motor_theft_g["weights"] = float(0.0001836547)
theft_g["weights"] = float(0.0004075643)

# %%
ax1 = gplt.polyplot(df_neighborhoods["geometry"].explode(ignore_index=True),    zorder=-1,
    linewidth=1,
    edgecolor='black',
    facecolor='lightgray',
    figsize=(30, 30))
gplt.pointplot(theft_g,legend_kwargs={ "marker":'o',"markersize": "0.1"}, ax=ax1)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[369], line 6
#       1 ax1 = gplt.polyplot(df_neighborhoods["geometry"].explode(ignore_index=True),    zorder=-1,
#       2     linewidth=1,
#       3     edgecolor='white',
#       4     facecolor='lightgray',
#       5     figsize=(30, 30))
# ----> 6 gplt.pointplot(theft_g,legend_kwargs={ "marker":'o',"markersize": "0.1"},clip=(df_neighborhoods["geometry"].explode(ignore_index=True)), ax=ax1)
#
# File ~/anaconda3/lib/python3.10/site-packages/geoplot/geoplot.py:829, in pointplot(df, projection, hue, cmap, norm, scheme, scale, limits, scale_func, legend, legend_var, legend_values, legend_labels, legend_kwargs, figsize, extent, ax, **kwargs)
#     819         return ax
#     821 plot = PointPlot(
#     822     df, figsize=figsize, ax=ax, extent=extent, projection=projection,
#     823     hue=hue, scheme=scheme, cmap=cmap, norm=norm,
#    (...)
#     827     **kwargs
#     828 )
# --> 829 return plot.draw()
#
# File ~/anaconda3/lib/python3.10/site-packages/geoplot/geoplot.py:818, in pointplot.<locals>.PointPlot.draw(self)
#     809     ax.scatter(
#     810         xs, ys, transform=ccrs.PlateCarree(), c=plot.colors,
#     811         # the ax.scatter 's' param is an area but the API is unified on width in pixels
#    (...)
#     815         **plot.kwargs
#     816     )
#     817 else:
# --> 818     ax.scatter(xs, ys, c=plot.colors, s=[s**2 for s in plot.sizes], **plot.kwargs)
#     819 return ax
#
# File ~/anaconda3/lib/python3.10/site-packages/matplotlib/__init__.py:1442, in _preprocess_data.<locals>.inner(ax, data, *args, **kwargs)
#    1439 @functools.wraps(func)
#    1440 def inner(ax, *args, data=None, **kwargs):
#    1441     if data is None:
# -> 1442         return func(ax, *map(sanitize_sequence, args), **kwargs)
#    1444     bound = new_sig.bind(ax, *args, **kwargs)
#    1445     auto_label = (bound.arguments.get(label_namer)
#    1446                   or bound.kwargs.get(label_namer))
#
# File ~/anaconda3/lib/python3.10/site-packages/matplotlib/axes/_axes.py:4698, in Axes.scatter(self, x, y, s, c, marker, cmap, norm, vmin, vmax, alpha, linewidths, edgecolors, plotnonfinite, **kwargs)
#    4694         keys_str = ", ".join(f"'{k}'" for k in extra_keys)
#    4695         _api.warn_external(
#    4696             "No data for colormapping provided via 'c'. "
#    4697             f"Parameters {keys_str} will be ignored")
# -> 4698 collection._internal_update(kwargs)
#    4700 # Classic mode only:
#    4701 # ensure there are margins to allow for the
#    4702 # finite size of the symbols.  In v2.x, margins
#    4703 # are present by default, so we disable this
#    4704 # scatter-specific override.
#    4705 if mpl.rcParams['_internal.classic_mode']:
#
# File ~/anaconda3/lib/python3.10/site-packages/matplotlib/artist.py:1223, in Artist._internal_update(self, kwargs)
#    1216 def _internal_update(self, kwargs):
#    1217     """
#    1218     Update artist properties without prenormalizing them, but generating
#    1219     errors as if calling `set`.
#    1220
#    1221     The lack of prenormalization is to maintain backcompatibility.
#    1222     """
# -> 1223     return self._update_props(
#    1224         kwargs, "{cls.__name__}.set() got an unexpected keyword argument "
#    1225         "{prop_name!r}")
#
# File ~/anaconda3/lib/python3.10/site-packages/matplotlib/artist.py:1197, in Artist._update_props(self, props, errfmt)
#    1195             func = getattr(self, f"set_{k}", None)
#    1196             if not callable(func):
# -> 1197                 raise AttributeError(
#    1198                     errfmt.format(cls=type(self), prop_name=k))
#    1199             ret.append(func(v))
#    1200 if ret:
#
# AttributeError: PathCollection.set() got an unexpected keyword argument 'clip'

# %%
ax2 = gplt.polyplot(df_neighborhoods["geometry"].explode(),linewidth=1 ,  edgecolor='black',
    facecolor='lightgray', figsize=(30,30))
gplt.pointplot(motor_theft_g,legend_kwargs={ "marker":'o',"markersize": "0.1"}, ax=ax2)
# Out:
# /var/folders/q2/blj1b35943190bxj_nqhbpy0w9ff45/T/ipykernel_5561/3825684158.py:1: FutureWarning: Currently, index_parts defaults to True, but in the future, it will default to False to be consistent with Pandas. Use `index_parts=True` to keep the current behavior and True/False to silence the warning.
#   ax2 = gplt.polyplot(df_neighborhoods["geometry"].explode(),linewidth=1 ,  edgecolor='white',
# <Axes: >

# %%
motor_theft_kde = gplt.kdeplot(motor_theft_g,  cmap='Reds')

# %%
theft_kde = gplt.kdeplot(theft_g, cmap='Reds', legend=True)

# %%
ax = gplt.webmap(contiguous_usa, projection=gplt.crs.WebMercator())
gplt.pointplot(continental_usa_cities, ax=ax, hue='ELEV_IN_FT', legend=True)

# %%
import geoplot as gplt
import geoplot.crs as gcrs
import geopandas as gpd

boroughs = gpd.read_file(gplt.datasets.get_path('nyc_boroughs'))
collisions = gpd.read_file(gplt.datasets.get_path('nyc_collision_factors'))

gplt.pointplot(collisions)

# %%
ax = gplt.kdeplot(collisions, cmap='Reds', shade=False, projection=gcrs.AlbersEqualArea())
# Out:
# /Users/tony.qing/anaconda3/lib/python3.10/site-packages/geoplot/geoplot.py:1304: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=False`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(

# %%
polygons = []
for i in a.get_children():
    if str(type(i)) == "<class 'matplotlib.collections.PathCollection'>":
        for path in i.get_paths():
            polygons.append(Polygon(path.to_polygons()[0]))

# %%
heatmap = gpd.GeoDataFrame(geometry=polygons)

# %%
heatmap.plot(edgecolor="black")
