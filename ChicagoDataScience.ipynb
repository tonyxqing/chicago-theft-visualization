# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (eg. pd.read_csv)

# Input data files are available in the "../input/" directory.
# For example, running this (by clicking run or pressing Shift+Enter) will list the files in the input directory

import os
print(os.listdir("./src"))
# Out:
# ['.DS_Store', 'app.d.ts', 'crimeData.ts', 'chicago.ts', 'Boundaries - Neighborhoods.json', 'app.html', 'routes']

# %%
#df stands for dataframe which is the standard structure used by pandas
df = pd.read_csv('Crimes_-_Map.csv')

df.head()
# Out:
#       CASE#     DATE  OF OCCURRENCE                  BLOCK  IUCR  \
# 0  JF238175  05/11/2022 11:25:00 AM     002XX W MADISON ST  0860
# 1  JF228949  04/25/2022 12:00:00 PM  010XX W DIVERSEY PKWY  0890
# 2  JF186941  03/25/2022 07:55:00 PM        021XX W 21ST ST  0810
# 3  JF293270  06/24/2022 01:00:00 AM  054XX S Ingleside Ave  0810
# 4  JF361213  08/16/2022 09:00:00 AM      013XX W FULTON ST  0810
#
#    PRIMARY DESCRIPTION  SECONDARY DESCRIPTION  \
# 0                THEFT           RETAIL THEFT
# 1                THEFT          FROM BUILDING
# 2                THEFT              OVER $500
# 3                THEFT              OVER $500
# 4                THEFT              OVER $500
#
#                      LOCATION DESCRIPTION ARREST DOMESTIC  BEAT  WARD FBI CD  \
# 0                              DRUG STORE      N        N   122  42.0     06
# 1                      RESIDENCE - GARAGE      N        N  1933  44.0     06
# ...

# %%
import folium
import matplotlib.pyplot as plt
import seaborn as sns

# %%
plt.figure(figsize=(10,7))
sns.heatmap(df.isnull(), cbar = False, cmap = 'viridis')
# Out:
# <Axes: >

# %%
df = df.dropna()

df = df.drop( 'LOCATION', axis=1)

# %%
df.to_csv("./crime_map.csv")

# %%
import geopandas as gpd

# %%
df_places = gpd.read_file('./src/Boundaries - Neighborhoods.json')

# %%
df_places.plot()
# Out:
# <Axes: >

# %%
df.dtypes
# Out:
# CASE#                      object
# DATE  OF OCCURRENCE        object
# BLOCK                      object
#  IUCR                      object
#  PRIMARY DESCRIPTION       object
#  SECONDARY DESCRIPTION     object
#  LOCATION DESCRIPTION      object
# ARREST                     object
# DOMESTIC                   object
# BEAT                        int64
# WARD                      float64
# FBI CD                     object
# X COORDINATE              float64
# Y COORDINATE              float64
# LATITUDE                  float64
# LONGITUDE                 float64
# dtype: object
